# %%
# ============================================================
# 02_authorweight_tda
# Purpose:
#   - load authorweight_df from 01_author_replication
#   - build pre-treatment standardized level series
#   - run TDA for multiple embeddings:
#       (2,1), (3,1), (4,1), (3,2)
#   - save all plots as PDF
#   - save summary table as CSV
# ============================================================

import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from ripser import ripser
from persim import plot_diagrams, bottleneck, wasserstein

# ------------------------------------------------------------
# 0) Paths
# ------------------------------------------------------------
INPUT_DIR = "outputs_authorweight"
OUTPUT_DIR = "outputs_authorweight_tda"
os.makedirs(OUTPUT_DIR, exist_ok=True)

AUTHOR_DF_PATH = os.path.join(INPUT_DIR, "authorweight_df.csv")

# ------------------------------------------------------------
# 1) Load data
# ------------------------------------------------------------
authorweight_df = pd.read_csv(AUTHOR_DF_PATH)
authorweight_df["date"] = pd.to_datetime(authorweight_df["date"])

print("Loaded authorweight_df:")
print(authorweight_df.head())
print("\nColumns:", authorweight_df.columns.tolist())

if "treated" not in authorweight_df.columns:
    raise ValueError("Cannot find 'treated' column in authorweight_df.")

if "synthetic_author" not in authorweight_df.columns:
    raise ValueError("Cannot find 'synthetic_author' column in authorweight_df.")

# ------------------------------------------------------------
# 2) Basic settings
# ------------------------------------------------------------
treatment_start = pd.Timestamp("2011-04-01")

# ------------------------------------------------------------
# 3) Extract pre-treatment levels
# ------------------------------------------------------------
pre_levels = authorweight_df.loc[
    authorweight_df["date"] < treatment_start,
    ["date", "treated", "synthetic_author"]
].copy()

pre_levels = pre_levels.rename(columns={"synthetic_author": "synthetic"})
pre_levels = pre_levels.sort_values("date").reset_index(drop=True)

print("\nPretreatment sample:")
print("  first date:", pre_levels["date"].min().date())
print("  last  date:", pre_levels["date"].max().date())
print("  n periods :", len(pre_levels))

# save raw pre-treatment level series
pre_levels.to_csv(os.path.join(OUTPUT_DIR, "authorweight_pre_levels.csv"), index=False)

# ------------------------------------------------------------
# 4) Standardize each series separately
# ------------------------------------------------------------
def zscore(x):
    x = np.asarray(x, dtype=float)
    s = x.std(ddof=0)
    if s == 0:
        return np.zeros_like(x)
    return (x - x.mean()) / s

pre_levels["treated_z"] = zscore(pre_levels["treated"])
pre_levels["synthetic_z"] = zscore(pre_levels["synthetic"])

# save standardized series
pre_levels.to_csv(os.path.join(OUTPUT_DIR, "authorweight_pre_levels_standardized.csv"), index=False)

# ------------------------------------------------------------
# 5) Plot standardized level series
# ------------------------------------------------------------
fig, ax = plt.subplots(figsize=(9, 4.8))
ax.plot(pre_levels["date"], pre_levels["treated_z"], label="Missouri", linewidth=1.8)
ax.plot(pre_levels["date"], pre_levels["synthetic_z"], label="Synthetic control (author weights)", linewidth=1.8)
ax.axhline(0, color="lightgray", linewidth=1)

ax.set_title("Pre-treatment Standardized Level Series (Author Weights)")
ax.set_ylabel("Standardized value")
ax.set_xlabel("Date")
ax.legend()
ax.spines["top"].set_visible(False)
ax.spines["right"].set_visible(False)

plt.tight_layout()
plt.savefig(
    os.path.join(OUTPUT_DIR, "authorweight_standardized_pre_series.pdf"),
    bbox_inches="tight"
)
plt.show()

# ------------------------------------------------------------
# 6) Delay embedding helper
# ------------------------------------------------------------
def delay_embed(x, dim=3, delay=1):
    x = np.asarray(x, dtype=float)
    n = len(x) - (dim - 1) * delay
    if n <= 0:
        raise ValueError(
            f"Series too short for requested embedding: len={len(x)}, dim={dim}, delay={delay}"
        )
    return np.column_stack([x[i:i+n] for i in range(0, dim * delay, delay)])

# ------------------------------------------------------------
# 7) TDA helper functions
# ------------------------------------------------------------
def finite_diagram(dgm):
    dgm = np.asarray(dgm, dtype=float)
    if dgm.size == 0:
        return dgm.reshape(0, 2)
    return dgm[np.isfinite(dgm[:, 1])]

def persistence_summary(dgm):
    dgm = np.asarray(dgm, dtype=float)
    if dgm.size == 0:
        return {
            "n_features": 0,
            "max_persistence": 0.0,
            "total_persistence": 0.0,
            "mean_persistence": 0.0
        }

    pers = dgm[:, 1] - dgm[:, 0]
    pers = pers[np.isfinite(pers)]

    if len(pers) == 0:
        return {
            "n_features": 0,
            "max_persistence": 0.0,
            "total_persistence": 0.0,
            "mean_persistence": 0.0
        }

    return {
        "n_features": int(len(pers)),
        "max_persistence": float(np.max(pers)),
        "total_persistence": float(np.sum(pers)),
        "mean_persistence": float(np.mean(pers))
    }

def plot_single_barcode(ax, dgm, title="Persistent barcode", color="C0"):
    dgm = np.asarray(dgm, dtype=float)

    if dgm.size == 0:
        ax.set_title(title)
        ax.text(
            0.5, 0.5, "No finite features",
            ha="center", va="center", transform=ax.transAxes
        )
        ax.set_xlabel("Filtration value")
        ax.set_yticks([])
        ax.spines["top"].set_visible(False)
        ax.spines["right"].set_visible(False)
        return

    pers = dgm[:, 1] - dgm[:, 0]
    order = np.argsort(-pers)
    dgm = dgm[order]

    for i, (birth, death) in enumerate(dgm):
        ax.hlines(i, birth, death, linewidth=2, color=color)

    xmin, xmax = np.min(dgm[:, 0]), np.max(dgm[:, 1])
    pad = 0.05 * (xmax - xmin + 1e-8)
    ax.set_xlim(xmin - pad, xmax + pad)

    ax.set_title(title)
    ax.set_xlabel("Filtration value")
    ax.set_ylabel("Feature index")
    ax.invert_yaxis()
    ax.spines["top"].set_visible(False)
    ax.spines["right"].set_visible(False)

# ------------------------------------------------------------
# 8) Embedding specifications
# ------------------------------------------------------------
embedding_specs = [
    (2, 1),
    (3, 1),
    (4, 1),
    (3, 2),
]

summary_rows = []

# ------------------------------------------------------------
# 9) Run each embedding
# ------------------------------------------------------------
for embed_dim, embed_delay in embedding_specs:
    emb_label = f"({embed_dim},{embed_delay})"
    emb_tag = f"{embed_dim}_{embed_delay}"

    print("\n" + "=" * 70)
    print(f"Running embedding {emb_label}")
    print("=" * 70)

    # --------------------------------------------------------
    # 9.1 Build point clouds
    # --------------------------------------------------------
    treated_pc = delay_embed(pre_levels["treated_z"], dim=embed_dim, delay=embed_delay)
    synthetic_pc = delay_embed(pre_levels["synthetic_z"], dim=embed_dim, delay=embed_delay)

    print("treated point cloud shape  :", treated_pc.shape)
    print("synthetic point cloud shape:", synthetic_pc.shape)

    # save point clouds
    treated_pc_df = pd.DataFrame(treated_pc)
    synthetic_pc_df = pd.DataFrame(synthetic_pc)

    treated_pc_df.to_csv(
        os.path.join(OUTPUT_DIR, f"authorweight_treated_embedding_{emb_tag}.csv"),
        index=False
    )
    synthetic_pc_df.to_csv(
        os.path.join(OUTPUT_DIR, f"authorweight_synthetic_embedding_{emb_tag}.csv"),
        index=False
    )

    # --------------------------------------------------------
    # 9.2 Plot embedding scatter
    # --------------------------------------------------------
    fig, axes = plt.subplots(1, 2, figsize=(10, 4.2))

    axes[0].scatter(treated_pc[:, 0], treated_pc[:, 1], s=20)
    axes[0].set_title(f"Missouri embedding {emb_label}")

    axes[1].scatter(synthetic_pc[:, 0], synthetic_pc[:, 1], s=20)
    axes[1].set_title(f"Synthetic embedding {emb_label}")

    plt.tight_layout()
    plt.savefig(
        os.path.join(OUTPUT_DIR, f"authorweight_embedding_{emb_tag}.pdf"),
        bbox_inches="tight"
    )
    plt.show()

    # --------------------------------------------------------
    # 9.3 Persistent homology
    # --------------------------------------------------------
    treated_ph = ripser(treated_pc, maxdim=1)
    synthetic_ph = ripser(synthetic_pc, maxdim=1)

    treated_dgm0, treated_dgm1 = treated_ph["dgms"]
    synthetic_dgm0, synthetic_dgm1 = synthetic_ph["dgms"]

    # save raw diagrams
    pd.DataFrame(treated_dgm0, columns=["birth", "death"]).to_csv(
        os.path.join(OUTPUT_DIR, f"authorweight_treated_H0_diagram_{emb_tag}.csv"),
        index=False
    )
    pd.DataFrame(treated_dgm1, columns=["birth", "death"]).to_csv(
        os.path.join(OUTPUT_DIR, f"authorweight_treated_H1_diagram_{emb_tag}.csv"),
        index=False
    )
    pd.DataFrame(synthetic_dgm0, columns=["birth", "death"]).to_csv(
        os.path.join(OUTPUT_DIR, f"authorweight_synthetic_H0_diagram_{emb_tag}.csv"),
        index=False
    )
    pd.DataFrame(synthetic_dgm1, columns=["birth", "death"]).to_csv(
        os.path.join(OUTPUT_DIR, f"authorweight_synthetic_H1_diagram_{emb_tag}.csv"),
        index=False
    )

    # --------------------------------------------------------
    # 9.4 Plot persistence diagrams
    # --------------------------------------------------------
    fig, axes = plt.subplots(1, 2, figsize=(10, 4.2))

    plot_diagrams([treated_dgm0, treated_dgm1], ax=axes[0], show=False)
    axes[0].set_title(f"Missouri persistence diagrams {emb_label}")

    plot_diagrams([synthetic_dgm0, synthetic_dgm1], ax=axes[1], show=False)
    axes[1].set_title(f"Synthetic persistence diagrams {emb_label}")

    plt.tight_layout()
    plt.savefig(
        os.path.join(OUTPUT_DIR, f"authorweight_persistence_diagrams_{emb_tag}.pdf"),
        bbox_inches="tight"
    )
    plt.show()

    # --------------------------------------------------------
    # 9.5 Finite diagrams for barcode + distances
    # --------------------------------------------------------
    treated_dgm0_f = finite_diagram(treated_dgm0)
    treated_dgm1_f = finite_diagram(treated_dgm1)
    synthetic_dgm0_f = finite_diagram(synthetic_dgm0)
    synthetic_dgm1_f = finite_diagram(synthetic_dgm1)

    # --------------------------------------------------------
    # 9.6 Plot persistent barcodes
    # --------------------------------------------------------
    fig, axes = plt.subplots(2, 2, figsize=(12, 8))

    # H0
    plot_single_barcode(
        axes[0, 0], treated_dgm0_f,
        title=f"Missouri H0 barcode {emb_label}", color="C0"
    )
    plot_single_barcode(
        axes[1, 0], synthetic_dgm0_f,
        title=f"Synthetic H0 barcode {emb_label}", color="C0"
    )

    # H1
    plot_single_barcode(
        axes[0, 1], treated_dgm1_f,
        title=f"Missouri H1 barcode {emb_label}", color="red"
    )
    plot_single_barcode(
        axes[1, 1], synthetic_dgm1_f,
        title=f"Synthetic H1 barcode {emb_label}", color="red"
    )

    plt.tight_layout()
    plt.savefig(
        os.path.join(OUTPUT_DIR, f"authorweight_barcodes_{emb_tag}.pdf"),
        bbox_inches="tight"
    )
    plt.show()

    # --------------------------------------------------------
    # 9.7 Summaries
    # --------------------------------------------------------
    mo_h0 = persistence_summary(treated_dgm0_f)
    mo_h1 = persistence_summary(treated_dgm1_f)
    syn_h0 = persistence_summary(synthetic_dgm0_f)
    syn_h1 = persistence_summary(synthetic_dgm1_f)

    h0_bottle = bottleneck(treated_dgm0_f, synthetic_dgm0_f)
    h0_wass = wasserstein(treated_dgm0_f, synthetic_dgm0_f)
    h1_bottle = bottleneck(treated_dgm1_f, synthetic_dgm1_f)
    h1_wass = wasserstein(treated_dgm1_f, synthetic_dgm1_f)

    print(f"\nEmbedding {emb_label} summaries")
    print("Missouri H0:", mo_h0)
    print("Missouri H1:", mo_h1)
    print("Synthetic H0:", syn_h0)
    print("Synthetic H1:", syn_h1)
    print("H0 bottleneck :", h0_bottle)
    print("H0 wasserstein:", h0_wass)
    print("H1 bottleneck :", h1_bottle)
    print("H1 wasserstein:", h1_wass)

    summary_rows.append({
        "embedding": emb_label,
        "dim": embed_dim,
        "delay": embed_delay,
        "n_points": treated_pc.shape[0],

        "H0_bottleneck": h0_bottle,
        "H0_wasserstein": h0_wass,
        "H1_bottleneck": h1_bottle,
        "H1_wasserstein": h1_wass,

        "MO_H0_n": mo_h0["n_features"],
        "MO_H0_maxpers": mo_h0["max_persistence"],
        "MO_H0_totalpers": mo_h0["total_persistence"],
        "MO_H0_meanpers": mo_h0["mean_persistence"],

        "SYN_H0_n": syn_h0["n_features"],
        "SYN_H0_maxpers": syn_h0["max_persistence"],
        "SYN_H0_totalpers": syn_h0["total_persistence"],
        "SYN_H0_meanpers": syn_h0["mean_persistence"],

        "MO_H1_n": mo_h1["n_features"],
        "MO_H1_maxpers": mo_h1["max_persistence"],
        "MO_H1_totalpers": mo_h1["total_persistence"],
        "MO_H1_meanpers": mo_h1["mean_persistence"],

        "SYN_H1_n": syn_h1["n_features"],
        "SYN_H1_maxpers": syn_h1["max_persistence"],
        "SYN_H1_totalpers": syn_h1["total_persistence"],
        "SYN_H1_meanpers": syn_h1["mean_persistence"],
    })

# ------------------------------------------------------------
# 10) Summary table
# ------------------------------------------------------------
summary_df = pd.DataFrame(summary_rows)

print("\n=== EMBEDDING SUMMARY TABLE ===")
print(summary_df.to_string(index=False))

summary_df.to_csv(
    os.path.join(OUTPUT_DIR, "authorweight_embedding_summary.csv"),
    index=False
)

# also save as a simple txt printout
with open(os.path.join(OUTPUT_DIR, "authorweight_embedding_summary.txt"), "w", encoding="utf-8") as f:
    f.write("=== EMBEDDING SUMMARY TABLE ===\n")
    f.write(summary_df.to_string(index=False))

print(f"\nSaved outputs in: {OUTPUT_DIR}")
print(" - authorweight_pre_levels.csv")
print(" - authorweight_pre_levels_standardized.csv")
print(" - authorweight_standardized_pre_series.pdf")
print(" - authorweight_embedding_summary.csv")
print(" - authorweight_embedding_summary.txt")
print(" - per-embedding embedding/diagram/barcode pdfs")
print(" - per-embedding point-cloud and diagram csvs")
# Out:
# Loaded authorweight_df:
#    mo_yr       date  ALABAMA        ALASKA  ARIZONA  CALIFORNIA  COLORADO  \
# 0    397 2009-01-01     3.76 -1.800001e-01     3.12        3.64      1.10
# 1    398 2009-02-01     4.74  2.864000e-07     3.56        4.24      1.50
# 2    399 2009-03-01     5.04  3.000003e-01     3.78        4.46      1.70
# 3    400 2009-04-01     5.12  4.400002e-01     3.84        4.44      1.84
# 4    401 2009-05-01     5.76  6.199999e-01     4.32        4.98      2.14
#
#    CONNECTICUT  DELAWARE  DISTRICT OF COLUMBIA  ...  VERMONT  VIRGINIA  \
# 0         2.48      3.24                  1.26  ...     2.36      2.10
# 1         2.70      3.66                  1.54  ...     2.78      2.42
# 2         2.88      3.92                  1.74  ...     3.24      2.70
# 3         3.06      4.14                  2.10  ...     3.40      2.64
# 4         3.08      4.44                  2.34  ...     3.38      3.00
#
#    WASHINGTON  WEST VIRGINIA  WISCONSIN  WYOMING  synthetic_author  treated  \
# 0        0.54           0.22       2.00     0.34          2.998002     3.10
# 1        1.08           0.86       2.68     1.00          3.395085     3.64
# 2        1.38           1.52       3.30     1.86          3.602218     3.54
# 3        1.74           2.12       3.42     2.84          3.672867     3.12
# 4        2.30           2.58       3.70     2.78          3.972428     3.92
#
#    gap_raw_author  gap_centered_author
# 0        0.101997             0.059100
# 1        0.244915             0.202018
# 2       -0.062217            -0.105114
# 3       -0.552867            -0.595764
# 4       -0.052428            -0.095325
#
# [5 rows x 52 columns]
#
# Columns: ['mo_yr', 'date', 'ALABAMA', 'ALASKA', 'ARIZONA', 'CALIFORNIA', 'COLORADO', 'CONNECTICUT', 'DELAWARE', 'DISTRICT OF COLUMBIA', 'HAWAII', 'IDAHO', 'ILLINOIS', 'INDIANA', 'IOWA', 'KANSAS', 'KENTUCKY', 'LOUISIANA', 'MAINE', 'MARYLAND', 'MASSACHUSETTS', 'MINNESOTA', 'MISSISSIPPI', 'MISSOURI', 'MONTANA', 'NEBRASKA', 'NEVADA', 'NEW HAMPSHIRE', 'NEW JERSEY', 'NEW MEXICO', 'NEW YORK', 'NORTH CAROLINA', 'NORTH DAKOTA', 'OHIO', 'OKLAHOMA', 'OREGON', 'PENNSYLVANIA', 'RHODE ISLAND', 'SOUTH DAKOTA', 'TENNESSEE', 'TEXAS', 'UTAH', 'VERMONT', 'VIRGINIA', 'WASHINGTON', 'WEST VIRGINIA', 'WISCONSIN', 'WYOMING', 'synthetic_author', 'treated', 'gap_raw_author', 'gap_centered_author']
#
# Pretreatment sample:
#   first date: 2009-01-01
#   last  date: 2011-03-01
#   n periods : 27
# ======================================================================
# Running embedding (2,1)
# ======================================================================
# treated point cloud shape  : (26, 2)
# synthetic point cloud shape: (26, 2)
# Embedding (2,1) summaries
# Missouri H0: {'n_features': 25, 'max_persistence': 1.4472205638885498, 'total_persistence': 11.123986929655075, 'mean_persistence': 0.444959477186203}
# Missouri H1: {'n_features': 2, 'max_persistence': 0.12631350755691528, 'total_persistence': 0.1819554567337036, 'mean_persistence': 0.0909777283668518}
# Synthetic H0: {'n_features': 25, 'max_persistence': 1.3189771175384521, 'total_persistence': 11.08467374369502, 'mean_persistence': 0.44338694974780085}
# Synthetic H1: {'n_features': 4, 'max_persistence': 0.2704998254776001, 'total_persistence': 0.5222674310207367, 'mean_persistence': 0.13056685775518417}
# H0 bottleneck : 0.16352546215057373
# H0 wasserstein: 1.177845124155283
# H1 bottleneck : 0.13524991273880005
# H1 wasserstein: 0.49335284072970714
#
# ======================================================================
# Running embedding (3,1)
# ======================================================================
# treated point cloud shape  : (25, 3)
# synthetic point cloud shape: (25, 3)
# Embedding (3,1) summaries
# Missouri H0: {'n_features': 24, 'max_persistence': 2.055481433868408, 'total_persistence': 17.81806281208992, 'mean_persistence': 0.74241928383708}
# Missouri H1: {'n_features': 7, 'max_persistence': 0.6197268962860107, 'total_persistence': 1.1870372295379639, 'mean_persistence': 0.16957674707685197}
# Synthetic H0: {'n_features': 24, 'max_persistence': 1.3352874517440796, 'total_persistence': 15.640926003456116, 'mean_persistence': 0.6517052501440048}
# Synthetic H1: {'n_features': 5, 'max_persistence': 0.3666408061981201, 'total_persistence': 0.6625221371650696, 'mean_persistence': 0.1325044274330139}
# H0 bottleneck : 0.7201939821243286
# H0 wasserstein: 3.2197459042072296
# H1 bottleneck : 0.30986344814300537
# H1 wasserstein: 1.131237277585226
#
# ======================================================================
# Running embedding (4,1)
# ======================================================================
# treated point cloud shape  : (24, 4)
# synthetic point cloud shape: (24, 4)
# Embedding (4,1) summaries
# Missouri H0: {'n_features': 23, 'max_persistence': 2.786376953125, 'total_persistence': 23.950746417045593, 'mean_persistence': 1.0413368007411128}
# Missouri H1: {'n_features': 6, 'max_persistence': 0.19007360935211182, 'total_persistence': 0.678368330001831, 'mean_persistence': 0.1130613883336385}
# Synthetic H0: {'n_features': 23, 'max_persistence': 1.6149295568466187, 'total_persistence': 19.650081664323807, 'mean_persistence': 0.8543513767097307}
# Synthetic H1: {'n_features': 3, 'max_persistence': 0.27969861030578613, 'total_persistence': 0.34740567207336426, 'mean_persistence': 0.11580189069112141}
# H0 bottleneck : 1.1714473962783813
# H0 wasserstein: 5.116797834634781
# H1 bottleneck : 0.13984930515289307
# H1 wasserstein: 0.7020351660354079
#
# ======================================================================
# Running embedding (3,2)
# ======================================================================
# treated point cloud shape  : (23, 3)
# synthetic point cloud shape: (23, 3)
# Embedding (3,2) summaries
# Missouri H0: {'n_features': 22, 'max_persistence': 1.8219358921051025, 'total_persistence': 17.533922031521797, 'mean_persistence': 0.7969964559782635}
# Missouri H1: {'n_features': 3, 'max_persistence': 0.06759530305862427, 'total_persistence': 0.09859955310821533, 'mean_persistence': 0.03286651770273844}
# Synthetic H0: {'n_features': 22, 'max_persistence': 1.195491909980774, 'total_persistence': 16.016615107655525, 'mean_persistence': 0.7280279594388875}
# Synthetic H1: {'n_features': 2, 'max_persistence': 0.08739417791366577, 'total_persistence': 0.11624354124069214, 'mean_persistence': 0.05812177062034607}
# H0 bottleneck : 0.6264439821243286
# H0 wasserstein: 2.491928219795227
# H1 bottleneck : 0.043697088956832886
# H1 wasserstein: 0.11965265932699598
#
# === EMBEDDING SUMMARY TABLE ===
# embedding  dim  delay  n_points  H0_bottleneck  H0_wasserstein  H1_bottleneck  H1_wasserstein  MO_H0_n  MO_H0_maxpers  MO_H0_totalpers  MO_H0_meanpers  SYN_H0_n  SYN_H0_maxpers  SYN_H0_totalpers  SYN_H0_meanpers  MO_H1_n  MO_H1_maxpers  MO_H1_totalpers  MO_H1_meanpers  SYN_H1_n  SYN_H1_maxpers  SYN_H1_totalpers  SYN_H1_meanpers
#     (2,1)    2      1        26       0.163525        1.177845       0.135250        0.493353       25       1.447221        11.123987        0.444959        25        1.318977         11.084674         0.443387        2       0.126314         0.181955        0.090978         4        0.270500          0.522267         0.130567
#     (3,1)    3      1        25       0.720194        3.219746       0.309863        1.131237       24       2.055481        17.818063        0.742419        24        1.335287         15.640926         0.651705        7       0.619727         1.187037        0.169577         5        0.366641          0.662522         0.132504
#     (4,1)    4      1        24       1.171447        5.116798       0.139849        0.702035       23       2.786377        23.950746        1.041337        23        1.614930         19.650082         0.854351        6       0.190074         0.678368        0.113061         3        0.279699          0.347406         0.115802
#     (3,2)    3      2        23       0.626444        2.491928       0.043697        0.119653       22       1.821936        17.533922        0.796996        22        1.195492         16.016615         0.728028        3       0.067595         0.098600        0.032867         2        0.087394          0.116244         0.058122
#
# Saved outputs in: outputs_authorweight_tda
#  - authorweight_pre_levels.csv
#  - authorweight_pre_levels_standardized.csv
#  - authorweight_standardized_pre_series.pdf
#  - authorweight_embedding_summary.csv
#  - authorweight_embedding_summary.txt
#  - per-embedding embedding/diagram/barcode pdfs
#  - per-embedding point-cloud and diagram csvs
